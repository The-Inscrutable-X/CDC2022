# %% [markdown]
# # ETL: Extract, Transform, Load

# %% [markdown]
# Extract, Transform, Load is one of the key components of data engineering.The basic idea is getting data from the source(s), manipulating them to be in a useful, correct format for downstream consumers, and moving them to a destination, usually some sort of centralized repository like a *datalake* or *datawarehouse*.
#
# This process can be done manually or scheduled to occur automatically, and there are several commercial software applications out there that can be leveraged as well, such as [snowflake](https://www.snowflake.com/guides/what-etl) or [databricks](https://www.databricks.com/glossary/extract-transform-load).
#
# There is also a slightly different pipline pattern, **ELT** during which raw data is all loaded into a central repository *first* and can then be transformed to meet various business needs later on.
#
# Example ETL use cases:
# * improve performance of an analytics dashboard
#     * pre-calculate as much as possible outside of tools like Tableau
#     * decreases load on dashboard and codifies/documents your data prep steps
#     * save space by limiting number of columns read in
# * central repository for data
#     * enforce data standards
#     * all downstream consumers starting with the same source data
#     * access data from multiple sources in one place

# %% [markdown]
# ## Extract: gather source data

# %% [markdown]
# ### Examples of Extraction Methods:
# * Read in a downloaded file (e.g. json or csv)
# * REST API requests
# * connect to a database and run a SQL query
# * connect to a cloud resource (e.g. streaming service, storage system)
# * parse web pages ([python web scraping libraries](https://towardsdatascience.com/choose-the-best-python-web-scraping-library-for-your-application-91a68bc81c4f))
# * connect to a sensor or other IOT data source

# %% [markdown]
# Today, we'll be extracting our data from a couple **API's**, or *application programming interface*.
#
# API's allow systems and computers to communicate. System A submits a *request* to System B, in a format System B can understand. Subsequently, System B will send a *response* containing the information requested by System A.
#
# **REST** stands for "**RE**presentational **S**tate **T**ransfer" and is a common architectural style for formatting API requests. Requests are formatted in an HTTP URI, and responses are delivered in one of several HTTP formats (e.g. JSON, XML, etc.)

# %%
# pip install requests
# pip install pandas

# %%
import os
import requests
import pandas as pd
import csv
import sys
from io import StringIO

# %% [markdown]
# #### Read in a CSV file

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\Hanqi-Xiao\\OneDrive - University of North Carolina at Chapel Hill\\Documents\\Python_scripts\\Pandas_and_matplot\\CDC_2022'

# %%
path = f"Flood_Health_Vulnerability.csv"

# %% [markdown]
# 1. Loop through a directory and create dataframes for each file

# %%
raw_frames = []
for filename in os.listdir(path):
    f = os.path.join(path, filename)
    # checking if it is a file
    if os.path.isfile(f):
        #.gz file indicates it's compressed. If you unzipped already or have downloaded a regular .csv file
        ## you can omit the gzip argument
        # make everything a string to maintain all data (e.g. id numbers with leading zeros)
        df = pd.read_csv(f, compression='gzip', dtype=str)
        raw_frames.append(df)
# Out:
# ----------------------------------------------------------------
# NotADirectoryError             Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 raw_frames = []
# ----> 2 for filename in os.listdir(path):
#       3     f = os.path.join(path, filename)
#       4     # checking if it is a file
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'Flood_Health_Vulnerability.csv'

# %% [markdown]
# 2. Merge the dataframes into one
# NOTE: concat and merge are two different pandas methods, we'll look at both in this demo. Here, we're using .merge to essentially "stack" dataframes with identical schemas on top of one another

# %%
raw_frames[1]
# Out:
# ----------------------------------------------------------------
# IndexError                     Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 raw_frames[1]
#
# IndexError: list index out of range

# %%
stormwater = pd.concat(raw_frames)

# %%
stormwater
# Out:
#       YEARMONTH EPISODE_ID EVENT_ID LOCATION_INDEX RANGE AZIMUTH  \
# 0        202008     152218   919675              1   .89      SE
# 1        202008     152218   919676              1  2.76       N
# 2        202008     152218   919677              1   .56       W
# 3        202008     152218   919679              1   .56       W
# 4        202008     152218   919680              1   .69       S
# ...         ...        ...      ...            ...   ...     ...
# 24519    202203     167113  1011295              1   .91      NW
# 24520    202203     167113  1011295              2   .62      NW
# 24521    202203     167113  1011295              3   .51      NW
# 24522    202203     167113  1011295              4   .77     NNW
# 24523    202203     167113  1011297              1   .69       N
#
#                    LOCATION LATITUDE LONGITUDE     LAT2     LON2
# 0                      EMIT    35.72    -78.26  3543200  7815600
# 1                 MIDDLESEX    35.82    -78.22  3549200  7813200
# 2      (RWI)ROCKY MT WILSON    35.85    -77.91  3551000  7754600
# 3                TIMBERLAKE    36.28    -78.96  3616800  7857600
# 4                  ROSEBORO    34.94    -78.53  3456400  7831800
# ...                     ...      ...       ...      ...      ...
# 24519          BRANNONVILLE    30.23     -85.6  3013800  8536000
# 24520          BRANNONVILLE  30.2257   -85.598  3013542  8535880
# 24521          BRANNONVILLE  30.2261  -85.5949  3013566  8535694
# 24522          BRANNONVILLE    30.23  -85.5956  3013800  8535736
# 24523          CAMP FLOWERS    30.33    -85.55  3019800  8533000
#
# [147030 rows x 11 columns]

# %% [markdown]
# #### Requesting data from an API

# %% [markdown]
# Data Sources:
# * [EPA Envirofacts](https://www.epa.gov/enviro/about-data)
# * [Census Bureau ACS](https://www.census.gov/data/developers/data-sets/acs-5year.html)

# %% [markdown]
# **EPA Greenhouse Gas Data**

# %% [markdown]
# We'll use the [requests](https://pypi.org/project/requests/) library to make our api calls:

# %%
gas_request = requests.get('https://data.epa.gov/efservice/PUB_DIM_GHG/EXCEL')

# %%
# metadata about the response
gas_request.headers
# Out:
# {'Date': 'Sat, 08 Oct 2022 15:29:11 GMT', 'Content-Type': 'application/vnd.ms-excel', 'Content-Length': '859', 'Connection': 'keep-alive', 'Server': 'nginx/1.21.6', 'Last-Modified': 'Sat, 08 Oct 2022 15:29:12 GMT', 'ETag': '"7c6a408139987d076cca29680efb5b58"', 'Content-Disposition': 'attachment;filename=EnvirofactsRestAPI.CSV', 'Accept-Ranges': 'bytes', 'X-XSS-Protection': '1; mode=block', 'X-Frame-Options': 'SAMEORIGIN', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'}

# %%
# response returned in CSV format (this particular table from EPA, only has XML and EXCEL as format options, normally
## JSON is the preferred response format if it's available, 
## as there's a lot of json support in python: https://docs.python.org/3/library/json.html)
gas_request.text
# Out:
# 'GAS_ID,GAS_CODE,GAS_NAME,GAS_LABEL\n"1","CO2","Carbon Dioxide","Carbon Dioxide (CO<sub>2</sub>)"\n"2","CH4","Methane","Methane (CH<sub>4</sub>)"\n"3","N2O","Nitrous Oxide","Nitrous Oxide (N<sub>2</sub>O)"\n"6","SF6","Sulfur Hexafluoride","Sulfur hexafluoride (SF<sub>6</sub>)"\n"7","CHF3","Fluoroform","HFC-23"\n"8","BIOCO2","Biogenic CO2","Biogenic Carbon Dioxide (CO<sub>2</sub>)"\n"9","NF3","Nitrogen Triflouride","Nitrogen trifluoride (NF<sub>3</sub>)"\n"10","HFC","HFCs","Hydrofluorocarbons (HFCs)"\n"11","PFC","PFCs","Perfluorocarbons (PFCs)"\n"12","HFE","HFEs","HFEs"\n"13","Other","Other","Other"\n"14","Other_L","Fluorinated GHG Production (CO<sub>2</sub>e)","Fluorinated GHG Production (CO<sub>2</sub>e)"\n"15","Very_Short","Very Short-lived Compounds","Very Short-lived Compounds"\n"16","Other_Full","Other Fully Fluorinated GHGs","Other Fully Fluorinated GHGs"\n'

# %%
gases = pd.read_csv(StringIO(gas_request.text))

# %%
gases
# Out:
#     GAS_ID    GAS_CODE                                      GAS_NAME  \
# 0        1         CO2                                Carbon Dioxide
# 1        2         CH4                                       Methane
# 2        3         N2O                                 Nitrous Oxide
# 3        6         SF6                           Sulfur Hexafluoride
# 4        7        CHF3                                    Fluoroform
# 5        8      BIOCO2                                  Biogenic CO2
# 6        9         NF3                          Nitrogen Triflouride
# 7       10         HFC                                          HFCs
# 8       11         PFC                                          PFCs
# 9       12         HFE                                          HFEs
# 10      13       Other                                         Other
# 11      14     Other_L  Fluorinated GHG Production (CO<sub>2</sub>e)
# 12      15  Very_Short                    Very Short-lived Compounds
# 13      16  Other_Full                  Other Fully Fluorinated GHGs
#
#                                        GAS_LABEL
# 0                Carbon Dioxide (CO<sub>2</sub>)
# 1                       Methane (CH<sub>4</sub>)
# 2                 Nitrous Oxide (N<sub>2</sub>O)
# 3           Sulfur hexafluoride (SF<sub>6</sub>)
# 4                                         HFC-23
# 5       Biogenic Carbon Dioxide (CO<sub>2</sub>)
# 6          Nitrogen trifluoride (NF<sub>3</sub>)
# 7                      Hydrofluorocarbons (HFCs)
# 8                        Perfluorocarbons (PFCs)
# 9                                           HFEs
# 10                                         Other
# 11  Fluorinated GHG Production (CO<sub>2</sub>e)
# 12                    Very Short-lived Compounds
# 13                  Other Fully Fluorinated GHGs

# %%
# pull data from other ghg tables
sector_request = requests.get('https://data.epa.gov/efservice/PUB_DIM_SECTOR/EXCEL')
sectors = pd.read_csv(StringIO(sector_request.text))
sub_sector_request = requests.get('https://data.epa.gov/efservice/PUB_DIM_SECTOR/EXCEL')
sub_sector = pd.read_csv(StringIO(sub_sector_request.text))

# %%
sectors
# Out:
#     SECTOR_ID          SECTOR_CODE  \
# 0           2                WASTE
# 1           3          POWERPLANTS
# 2           4           REFINERIES
# 3           5            CHEMICALS
# 4           6               METALS
# 5           7         PULPANDPAPER
# 6           8             MINERALS
# 7          14                OTHER
# 8           9  COAL_TO_LIQUIDS_SUP
# 9          10        PETROLEUM_SUP
# 10         11           NG_NGL_SUP
# 11         12               IG_SUP
# 12         13              CO2_SUP
# 13         15             PETRO_NG
# 14         17                  INJ
# 15         16                   QQ
#
#                                           SECTOR_NAME SECTOR_TYPE  \
# 0                                               Waste           E
# 1                                        Power Plants           E
# 2                                          Refineries           E
# 3                                           Chemicals           E
# 4                                              Metals           E
# 5                                      Pulp and Paper           E
# 6                                            Minerals           E
# 7                                               Other           E
# 8                       Coal-based Liquid Fuel Supply           S
# 9                         Petroleum Product Suppliers           S
# 10      Natural Gas and Natural Gas Liquids Suppliers           S
# 11                           Industrial Gas Suppliers           S
# 12                                   Suppliers of CO2           S
# 13                  Petroleum and Natural Gas Systems           E
# 14                                   Injection of CO2           I
# 15  Import and Export of Equipment Containing Fluo...           S
#
#    SECTOR_COLOR  SORT_ORDER
# 0       #9B9EBB         6.0
# 1       #FFBD59         1.0
# 2       #FFFF7F         3.0
# 3       #99D8F5         4.0
# 4       #B9B9CF         7.0
# 5       #D7D7E4         9.0
# 6       #DDEDF4         8.0
# 7       #C0E6E6         5.0
# 8           NaN         1.0
# 9           NaN         2.0
# 10          NaN         3.0
# 11          NaN         4.0
# 12          NaN         5.0
# 13      #F7D869         2.0
# 14          NaN         NaN
# 15          NaN         6.0

# %% [markdown]
# As we're going through the tables, this starts to feel repetitive... any repetitive action can usually be streamlined into a **LOOP**:

# %% [markdown]
# 1. Create list of our table names
# 2. Loop through the list, making the requests, and storing the responses in a pandas dataframe

# %%
tables = ['PUB_DIM_FACILITY', 'PUB_FACTS_SUBP_GHG_EMISSION',
         'PUB_DIM_SUBPART', 'PUB_DIM_GHG', 'PUB_FACTS_SECTOR_GHG_EMISSION',
         'PUB_DIM_SECTOR', 'PUB_DIM_SUBSECTOR']
# by storing these variables, I can easily update the code if the api
## location (url) or pipeline requirements change in the future
base_url = 'https://data.epa.gov/efservice/'
response_format = 'EXCEL'

# %%
# mapping table names to shorter, more convenient variables
table_map = {'PUB_DIM_FACILITY': 'facility', 
             'PUB_FACTS_SUBP_GHG_EMISSION': 'join_subpart_ghg',
             'PUB_DIM_SUBPART': 'subpart', 
             'PUB_DIM_GHG': 'ghg', 
             'PUB_FACTS_SECTOR_GHG_EMISSION': 'join_sector_ghg',
             'PUB_DIM_SECTOR': 'sector', 
             'PUB_DIM_SUBSECTOR': 'subsector'}

# %%
# dictionary to store our dataframes
dataframes = {}

for table in tables:
    table_request = requests.get(f'{base_url}/{table}/{response_format}')
    dataframes[table_map[table]] = pd.read_csv(StringIO(table_request.text), dtype=str)

# %%
# now all seven dataframes are available to us in the "dataframes" dictionary, via the mapped variable names
dataframes['sector']
# Out:
#    SECTOR_ID          SECTOR_CODE  \
# 0          2                WASTE
# 1          3          POWERPLANTS
# 2          4           REFINERIES
# 3          5            CHEMICALS
# 4          6               METALS
# 5          7         PULPANDPAPER
# 6          8             MINERALS
# 7         14                OTHER
# 8          9  COAL_TO_LIQUIDS_SUP
# 9         10        PETROLEUM_SUP
# 10        11           NG_NGL_SUP
# 11        12               IG_SUP
# 12        13              CO2_SUP
# 13        15             PETRO_NG
# 14        17                  INJ
# 15        16                   QQ
#
#                                           SECTOR_NAME SECTOR_TYPE  \
# 0                                               Waste           E
# 1                                        Power Plants           E
# 2                                          Refineries           E
# 3                                           Chemicals           E
# 4                                              Metals           E
# 5                                      Pulp and Paper           E
# 6                                            Minerals           E
# 7                                               Other           E
# 8                       Coal-based Liquid Fuel Supply           S
# 9                         Petroleum Product Suppliers           S
# 10      Natural Gas and Natural Gas Liquids Suppliers           S
# 11                           Industrial Gas Suppliers           S
# 12                                   Suppliers of CO2           S
# 13                  Petroleum and Natural Gas Systems           E
# 14                                   Injection of CO2           I
# 15  Import and Export of Equipment Containing Fluo...           S
#
#    SECTOR_COLOR SORT_ORDER
# 0       #9B9EBB          6
# 1       #FFBD59          1
# 2       #FFFF7F          3
# 3       #99D8F5          4
# 4       #B9B9CF          7
# 5       #D7D7E4          9
# 6       #DDEDF4          8
# 7       #C0E6E6          5
# 8           NaN          1
# 9           NaN          2
# 10          NaN          3
# 11          NaN          4
# 12          NaN          5
# 13      #F7D869          2
# 14          NaN        NaN
# 15          NaN          6

# %% [markdown]
# **Census Bureau American Community Survey 5-Year data**

# %%
mhi_request = requests.get('https://api.census.gov/data/2020/acs/acs5?get=NAME,B19013_001E&for=county:*')

# %%
mhi_text = mhi_request.text

# %%
mhi_text
# Out:
# '[["NAME","B19013_001E","state","county"],\n["Autauga County, Alabama","57982","01","001"],\n["Baldwin County, Alabama","61756","01","003"],\n["Barbour County, Alabama","34990","01","005"],\n["Bibb County, Alabama","51721","01","007"],\n["Blount County, Alabama","48922","01","009"],\n["Bullock County, Alabama","33866","01","011"],\n["Butler County, Alabama","44850","01","013"],\n["Calhoun County, Alabama","50128","01","015"],\n["Lewis County, Kentucky","29844","21","135"],\n["Lincoln County, Kentucky","42231","21","137"],\n["Livingston County, Kentucky","52795","21","139"],\n["Logan County, Kentucky","48912","21","141"],\n["Lyon County, Kentucky","49286","21","143"],\n["McCracken County, Kentucky","47011","21","145"],\n["McCreary County, Kentucky","29499","21","147"],\n["Madison County, Kentucky","51649","21","151"],\n["Marion County, Kentucky","43587","21","155"],\n["Marshall County, Kentucky","57348","21","157"],\n["Mason County, Kentucky","46241","21","161"],\n["Meade County, Kentucky","61500","21","163"],\n["Mercer County, Kentucky","52312","21","167"],\n["Metcalfe County, Kentucky","40391","21","169"],\n["Montgomery County, Kentucky","46998","21","173"],\n["Morgan County, Kentucky","37399","21","175"],\n["Nelson County, Kentucky","63032","21","179"],\n["Nicholas County, Kentucky","47665","21","181"],\n["Oldham County, Kentucky","103761","21","185"],\n["Owen County, Kentucky","50553","21","187"],\n["Pendleton County, Kentucky","56000","21","191"],\n["Pike County, Kentucky","34700","21","195"],\n["Powell County, Kentucky","41071","21","197"],\n["Robertson County, Kentucky","53074","21","201"],\n["Rockcastle County, Kentucky","38744","21","203"],\n["Russell County, Kentucky","41731","21","207"],\n["Scott County, Kentucky","71750","21","209"],\n["Simpson County, Kentucky","50159","21","213"],\n["Spencer County, Kentucky","85488","21","215"],\n["Todd County, Kentucky","47229","21","219"],\n["Trimble County, Kentucky","57589","21","223"],\n["Union County, Kentucky","49812","21","225"],\n["Washington County, Kentucky","55321","21","229"],\n["Wayne County, Kentucky","37678","21","231"],\n["Whitley County, Kentucky","39258","21","235"],\n["Wolfe County, Kentucky","22292","21","237"],\n["Androscoggin County, Maine","55002","23","001"],\n["Aroostook County, Maine","43791","23","003"],\n["Franklin County, Maine","51630","23","007"],\n["Hancock County, Maine","58345","23","009"],\n["Knox County, Maine","57794","23","013"],\n["Lincoln County, Maine","58125","23","015"],\n["Penobscot County, Maine","52128","23","019"],\n["Piscataquis County, Maine","42083","23","021"],\n["Somerset County, Maine","45382","23","025"],\n["Washington County, Maine","44847","23","029"],\n["York County, Maine","68932","23","031"],\n["Anoka County, Minnesota","84379","27","003"],\n["Becker County, Minnesota","60508","27","005"],\n["Beltrami County, Minnesota","50525","27","007"],\n["Benton County, Minnesota","60564","27","009"],\n["Big Stone County, Minnesota","55909","27","011"],\n["Blue Earth County, Minnesota","61058","27","013"],\n["Brown County, Minnesota","59804","27","015"],\n["Carlton County, Minnesota","66201","27","017"],\n["Carver County, Minnesota","104011","27","019"],\n["Cass County, Minnesota","53845","27","021"],\n["Chippewa County, Minnesota","57301","27","023"],\n["Chisago County, Minnesota","86900","27","025"],\n["Meigs County, Tennessee","50733","47","121"],\n["Montgomery County, Tennessee","60878","47","125"],\n["Moore County, Tennessee","63762","47","127"],\n["Obion County, Tennessee","39985","47","131"],\n["Overton County, Tennessee","36478","47","133"],\n["Pickett County, Tennessee","43125","47","137"],\n["Polk County, Tennessee","45326","47","139"],\n["Rhea County, Tennessee","46096","47","143"],\n["Roane County, Tennessee","55578","47","145"],\n["Rutherford County, Tennessee","68718","47","149"],\n["Scott County, Tennessee","37135","47","151"],\n["Sequatchie County, Tennessee","44217","47","153"],\n["Shelby County, Tennessee","52092", ...

# %%
mhi_text = mhi_text.replace('\n', '')

# %%
import ast

# %%
mhi_list = ast.literal_eval(mhi_text)

# %%
mhi = pd.DataFrame(mhi_list[1:], columns = mhi_list[0], dtype=str)

# %%
population_request = requests.get('https://api.census.gov/data/2020/acs/acs5?get=NAME,B01003_001E&for=county:*')
pop_text = population_request.text
pop_text = pop_text.replace('\n', '')
pop_list = ast.literal_eval(pop_text)

# %%
population = pd.DataFrame(pop_list[1:], columns = pop_list[0], dtype=str)

# %% [markdown]
# **CHALLENGE**: write a loop to make requests for multiple census variables at once (see the census api documentation for information on the variables available: https://www.census.gov/data/developers/data-sets/acs-5year.html#:~:text=2020%20ACS%20Detailed%20Tables%20Variables)

# %% [markdown]
# ## Transform
#
# Now that we have extracted data from a couple of sources, we want to combine and clean them so they are useful to us or other downstream consumers.
#
# **Common transformations**
# * select columns to load (i.e. drop unnecessary columns)
# * cast to correct datatype (we start with all strings to maintain all the raw data)
# * aggregate data (e.g. sum, count, minimum/maximum, etc.)
# * join data sources
# * derive new columns (e.g. split, concatenate, calculate new values, etc.)
# * validate data (fill in nulls, reject rows, fix incorrect values, etc.)

# %% [markdown]
# Current dataset variables: dataframes (dict), mhi, population

# %%
dataframes.keys()
# Out:
# dict_keys(['facility', 'join_subpart_ghg', 'subpart', 'ghg', 'join_sector_ghg', 'sector', 'subsector'])

# %%
mhi
# Out:
#                              NAME B19013_001E state county
# 0         Autauga County, Alabama       57982    01    001
# 1         Baldwin County, Alabama       61756    01    003
# 2         Barbour County, Alabama       34990    01    005
# 3            Bibb County, Alabama       51721    01    007
# 4          Blount County, Alabama       48922    01    009
# ...                           ...         ...   ...    ...
# 3216   Renville County, Minnesota       58542    27    129
# 3217     Roseau County, Minnesota       62304    27    135
# 3218  Sherburne County, Minnesota       88671    27    141
# 3219     Steele County, Minnesota       68172    27    147
# 3220       Todd County, Minnesota       54502    27    153
#
# [3221 rows x 4 columns]

# %%
population
# Out:
#                              NAME B01003_001E state county
# 0         Autauga County, Alabama       55639    01    001
# 1         Baldwin County, Alabama      218289    01    003
# 2         Barbour County, Alabama       25026    01    005
# 3            Bibb County, Alabama       22374    01    007
# 4          Blount County, Alabama       57755    01    009
# ...                           ...         ...   ...    ...
# 3216   Renville County, Minnesota       14572    27    129
# 3217     Roseau County, Minnesota       15259    27    135
# 3218  Sherburne County, Minnesota       96015    27    141
# 3219     Steele County, Minnesota       36710    27    147
# 3220       Todd County, Minnesota       24603    27    153
#
# [3221 rows x 4 columns]

# %% [markdown]
# #### Create new columns to join dataframes

# %% [markdown]
# Combine census dataframes
# 1. Create FIPS column -- county identifier for census data AND also a column in the facility GHG table
# 2. Join population and mhi data

# %%
dataframes['facility']
# Out:
#       FACILITY_ID    LATITUDE    LONGITUDE                CITY STATE    ZIP  \
# 0         1009051   37.795963  -122.022317           San Ramon    CA  94583
# 1         1008942    33.07567    -96.80594               Plano    TX  75024
# 2         1008914    32.75619    -97.33441          Fort Worth    TX  76102
# 3         1008688    32.00316   -102.07945             Midland    TX  79701
# 4         1008621    35.46734    -97.51406       Oklahoma City    OK  73102
# ...           ...         ...          ...                 ...   ...    ...
# 9996      1008897    42.45766    -83.65611          South Lyon    MI  48178
# 9997      1008673  40.7164495  -80.1205256  Cranberry Township    PA  16066
# 9998      1001085     39.4492     -84.4611             TRENTON    OH  45100
# 9999      1007870     28.4272     -81.5803    LAKE BUENA VISTA    FL  32830
# 10000     1001112     27.7886     -81.8694              BARTOW    FL  33830
#
#       COUNTY_FIPS          COUNTY                               ADDRESS1  \
# 0           06013    CONTRA COSTA             6001 Bollinger Canyon Road
# 1           48085          COLLIN                      5320 Legacy Drive
# 2           48439  TARRANT COUNTY            100 Throckmorton St., #1200
# 3           48329  MIDLAND COUNTY  600 North Marienfeld Street Suite 301
# 4           40109        Oklahoma                  333 West Sheridan Ave
# ...           ...             ...                                    ...
# 9996        26125  OAKLAND COUNTY                       400 South McMunn
# 9997          NaN             NaN         260 Executive Drive, Suite 100
# 9998        39017          Butler                      2100 WOODSDALE RD
# 9999        12095          Orange                 1375 Buena Vista Drive
# 10000       12105            Polk                   7700 COUNTY ROAD 555
#
#       ADDRESS2  ... PUBLIC_XML_XML REPORTED_INDUSTRY_TYPES  \
# 0          NaN  ...            NaN                  W-ONSH
# 1          NaN  ...            NaN                  W-ONSH
# 2          NaN  ...            NaN                  W-ONSH
# 3          NaN  ...            NaN                  W-ONSH
# 4          NaN  ...            NaN                  W-ONSH
# ...        ...  ...            ...                     ...
# 9996       NaN  ...            NaN                       C
# 9997       NaN  ...            NaN                  W-ONSH
# 9998       NaN  ...            NaN                     C,D
# 9999       NaN  ...            NaN              C,D,NN-LDC
# 10000      NaN  ...            NaN                     C,D
#
#                      FACILITY_TYPES SUBMISSION_ID UU_RD_EXEMPT  \
# 0      Onshore Oil & Gas Production        111373          NaN
# 1      Onshore Oil & Gas Production        110481          NaN
# 2      Onshore Oil & Gas Production        112161          NaN
# 3      Onshore Oil & Gas Production         65905          NaN
# 4      Onshore Oil & Gas Production         66924          NaN
# ...                             ...           ...          ...
# 9996                 Direct Emitter         41587          NaN
# 9997   Onshore Oil & Gas Production        109255          NaN
# 9998                 Direct Emitter         46466          NaN
# 9999       Supplier, Direct Emitter         51890          NaN
# 10000                Direct Emitter         45394          NaN
#
#       REPORTING_STATUS PROCESS_STATIONARY_CML COMMENTS RR_MRV_PLAN_URL  \
# 0                  NaN                    NaN      NaN             NaN
# 1                  NaN                    NaN      NaN             NaN
# 2                  NaN                    NaN      NaN             NaN
# 3                  NaN                    NaN      NaN             NaN
# 4                  NaN                    NaN      NaN             NaN
# ...                ...                    ...      ...             ...
# 9996               NaN                    NaN      NaN             NaN
# 9997               NaN                    NaN      NaN             NaN
# 9998               NaN                    NaN      NaN             NaN
# 9999               NaN                    NaN      NaN             NaN
# 10000              NaN                    NaN      NaN             NaN
#
#       RR_MONITORING_PLAN_FILENAME
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 9996                          NaN
# 9997                          NaN
# 9998                          NaN
# 9999                          NaN
# 10000                         NaN
#
# [10001 rows x 38 columns]

# %%
population['FIPS'] = population['state']+population['county']
population.head()
# Out:
#                       NAME B01003_001E state county   FIPS
# 0  Autauga County, Alabama       55639    01    001  01001
# 1  Baldwin County, Alabama      218289    01    003  01003
# 2  Barbour County, Alabama       25026    01    005  01005
# 3     Bibb County, Alabama       22374    01    007  01007
# 4   Blount County, Alabama       57755    01    009  01009

# %%
mhi['FIPS'] = mhi['state']+mhi['county']
mhi.head()
# Out:
#                       NAME B19013_001E state county   FIPS
# 0  Autauga County, Alabama       57982    01    001  01001
# 1  Baldwin County, Alabama       61756    01    003  01003
# 2  Barbour County, Alabama       34990    01    005  01005
# 3     Bibb County, Alabama       51721    01    007  01007
# 4   Blount County, Alabama       48922    01    009  01009

# %% [markdown]
# #### JOIN resources:
# * types of joins: https://www.w3schools.com/sql/sql_join.asp
# * joins/merges in python pandas: https://realpython.com/pandas-merge-join-and-concat/

# %%
census_data = population.merge(mhi, how='inner', on='FIPS')

# %%
# sanity check that no data was lost on our join
print(len(population), len(mhi), len(census_data))
# Out:
# 3221 3221 3221

# %%
census_data
# Out:
#                            NAME_x B01003_001E state_x county_x   FIPS  \
# 0         Autauga County, Alabama       55639      01      001  01001
# 1         Baldwin County, Alabama      218289      01      003  01003
# 2         Barbour County, Alabama       25026      01      005  01005
# 3            Bibb County, Alabama       22374      01      007  01007
# 4          Blount County, Alabama       57755      01      009  01009
# ...                           ...         ...     ...      ...    ...
# 3216   Renville County, Minnesota       14572      27      129  27129
# 3217     Roseau County, Minnesota       15259      27      135  27135
# 3218  Sherburne County, Minnesota       96015      27      141  27141
# 3219     Steele County, Minnesota       36710      27      147  27147
# 3220       Todd County, Minnesota       24603      27      153  27153
#
#                            NAME_y B19013_001E state_y county_y
# 0         Autauga County, Alabama       57982      01      001
# 1         Baldwin County, Alabama       61756      01      003
# 2         Barbour County, Alabama       34990      01      005
# 3            Bibb County, Alabama       51721      01      007
# 4          Blount County, Alabama       48922      01      009
# ...                           ...         ...     ...      ...
# 3216   Renville County, Minnesota       58542      27      129
# 3217     Roseau County, Minnesota       62304      27      135
# 3218  Sherburne County, Minnesota       88671      27      141
# 3219     Steele County, Minnesota       68172      27      147
# 3220       Todd County, Minnesota       54502      27      153
#
# [3221 rows x 9 columns]

# %%
# only keep the necessary columns
## rename columns to be more meaningful
census = census_data[['NAME_x', 'FIPS', 'B01003_001E', 'B19013_001E']]
census.columns = ['name', 'fips', 'population', 'mhi']

# %%
census
# Out:
#                              name   fips population    mhi
# 0         Autauga County, Alabama  01001      55639  57982
# 1         Baldwin County, Alabama  01003     218289  61756
# 2         Barbour County, Alabama  01005      25026  34990
# 3            Bibb County, Alabama  01007      22374  51721
# 4          Blount County, Alabama  01009      57755  48922
# ...                           ...    ...        ...    ...
# 3216   Renville County, Minnesota  27129      14572  58542
# 3217     Roseau County, Minnesota  27135      15259  62304
# 3218  Sherburne County, Minnesota  27141      96015  88671
# 3219     Steele County, Minnesota  27147      36710  68172
# 3220       Todd County, Minnesota  27153      24603  54502
#
# [3221 rows x 4 columns]

# %% [markdown]
# **Join dataframes from different sources**

# %%
print(len(census), len(dataframes['facility']))
# Out:
# 3221 10001

# %% [markdown]
# Keep all data for now

# %%
census_facility = dataframes['facility'].merge(census, how='left', left_on='COUNTY_FIPS', right_on='fips')

# %%
len(census_facility)
# Out:
# 10001

# %% [markdown]
# Investigate facilities that don't have census data

# %%
census_facility[census_facility['fips'].isna()]
# Out:
#      FACILITY_ID     LATITUDE     LONGITUDE                CITY STATE    ZIP  \
# 6        1008536     35.53376     -97.52976          Fort Worth    TX  76102
# 49       1012511     32.91606    -96.773085              Dallas    TX  75251
# 77       1011451    13.463579    144.678216                Piti    GU  96915
# 101      1010718   39.7541032  -105.0002242              Denver    CO  80202
# 190      1009797    28.979049      -91.4727            Offshore    LA  00000
# ...          ...          ...           ...                 ...   ...    ...
# 9821     1002569  28.15402604  -89.10355357            Offshore    LA  00000
# 9856     1000719   29.7765065   -95.4201377             Houston    TX  77007
# 9978     1009244   40.1064831  -108.8670246             Rangely    CO  81648
# 9995     1008670     40.49683      -79.8759          Pittsburgh    PA  15220
# 9997     1008673   40.7164495   -80.1205256  Cranberry Township    PA  16066
#
#      COUNTY_FIPS COUNTY                        ADDRESS1 ADDRESS2  ...  \
# 6            NaN    NaN     301 Commerce Dr. Suite 3701      NaN  ...
# 49           NaN    NaN      12377 Merit Dr. Suite 1200      NaN  ...
# 77         66010   GUAM              180 Cabras Highway      NaN  ...
# 101          NaN    NaN             1615 Wynkoop Street      NaN  ...
# 190          NaN    NaN                             NaN      NaN  ...
# ...          ...    ...                             ...      ...  ...
# 9821         NaN    NaN                             NaN      NaN  ...
# 9856         NaN    NaN       55 Waugh Drive, Suite 700      NaN  ...
# 9978         NaN    NaN                100 Chevron Road      NaN  ...
# 9995         NaN    NaN    651 Holiday Drive, Suite 300      NaN  ...
# 9997         NaN    NaN  260 Executive Drive, Suite 100      NaN  ...
#
#      UU_RD_EXEMPT REPORTING_STATUS PROCESS_STATIONARY_CML COMMENTS  \
# 6             NaN              NaN                    NaN      NaN
# 49            NaN              NaN                    NaN      NaN
# 77            NaN              NaN                    NaN      NaN
# 101           NaN              NaN                    NaN      NaN
# 190           NaN              NaN                    NaN      NaN
# ...           ...              ...                    ...      ...
# 9821          NaN              NaN                    NaN      NaN
# 9856          NaN              NaN                    NaN      NaN
# 9978          NaN              NaN                    NaN      NaN
# 9995          NaN              NaN                    NaN      NaN
# 9997          NaN              NaN                    NaN      NaN
#
#      RR_MRV_PLAN_URL RR_MONITORING_PLAN_FILENAME name fips population  mhi
# 6                NaN                         NaN  NaN  NaN        NaN  NaN
# 49               NaN                         NaN  NaN  NaN        NaN  NaN
# 77               NaN                         NaN  NaN  NaN        NaN  NaN
# 101              NaN                         NaN  NaN  NaN        NaN  NaN
# 190              NaN                         NaN  NaN  NaN        NaN  NaN
# ...              ...                         ...  ...  ...        ...  ...
# 9821             NaN                         NaN  NaN  NaN        NaN  NaN
# 9856             NaN                         NaN  NaN  NaN        NaN  NaN
# 9978             NaN                         NaN  NaN  NaN        NaN  NaN
# 9995             NaN                         NaN  NaN  NaN        NaN  NaN
# 9997             NaN                         NaN  NaN  NaN        NaN  NaN
#
# [231 rows x 42 columns]

# %%
census_facility[(census_facility['fips'].isna()) & ~(census_facility['COUNTY_FIPS'].isna())]
# Out:
#      FACILITY_ID   LATITUDE    LONGITUDE           CITY STATE    ZIP  \
# 77       1011451  13.463579   144.678216           Piti    GU  96915
# 912      1008001  17.750141   -64.714793  CHRISTIANSTED    VI  00820
# 3044     1004611  13.541741   144.807727         Dededo    GU  96929
# 8237     1006451    17.7102     -64.7544  CHRISTIANSTED    VI  00820
# 9470     1005781  61.084857  -146.388531         VALDEZ    AK  99686
# 9625     1008001  17.750141   -64.714793  CHRISTIANSTED    VI  00820
#
#      COUNTY_FIPS                      COUNTY             ADDRESS1 ADDRESS2  \
# 77         66010                        GUAM   180 Cabras Highway      NaN
# 912        78010            ST. CROIX ISLAND  1 Penitentiary Lane      NaN
# 3044       66010                        GUAM                  NCS      NaN
# 8237       78010            ST. CROIX ISLAND        1 ESTATE HOPE      NaN
# 9470       02261  VALDEZ-CORDOVA CENSUS AREA    300 DAYVILLE ROAD      NaN
# 9625       78010            ST. CROIX ISLAND  1 Penitentiary Lane      NaN
#
#       ... UU_RD_EXEMPT                REPORTING_STATUS PROCESS_STATIONARY_CML  \
# 77    ...          NaN                             NaN                    NaN
# 912   ...          NaN                             NaN                    NaN
# 3044  ...          NaN  STOPPED_REPORTING_VALID_REASON                    NaN
# 8237  ...          NaN                             NaN                    NaN
# 9470  ...          NaN                             NaN                    NaN
# 9625  ...          NaN                             NaN                    NaN
#
#      COMMENTS RR_MRV_PLAN_URL RR_MONITORING_PLAN_FILENAME name fips  \
# 77        NaN             NaN                         NaN  NaN  NaN
# 912       NaN             NaN                         NaN  NaN  NaN
# 3044      NaN             NaN                         NaN  NaN  NaN
# 8237      NaN             NaN                         NaN  NaN  NaN
# 9470      NaN             NaN                         NaN  NaN  NaN
# 9625      NaN             NaN                         NaN  NaN  NaN
#
#      population  mhi
# 77          NaN  NaN
# 912         NaN  NaN
# 3044        NaN  NaN
# 8237        NaN  NaN
# 9470        NaN  NaN
# 9625        NaN  NaN
#
# [6 rows x 42 columns]

# %% [markdown]
# At this point we can either decide to drop those rows, or try to fill them in somehow (e.g. assign them a county based on zip code)
#
# *NOTE: we would probably still drop the 5 non-continental US records (i.e. Guam and St. Croix island) and the "offshore" counties with 00000 zipcodes, even if we did try to fill in the other values*
#
# For now we'll just drop them. There's a couple of ways to do this:
# 1. inner join
# 2. remove rows based on a condition

# %%
len(census_facility) - len(census_facility[census_facility['fips'].isna()])
# Out:
# 9770

# %%
census_facility_inner = dataframes['facility'].merge(census, how='inner', left_on='COUNTY_FIPS', right_on='fips')

# %%
len(census_facility_inner)
# Out:
# 9770

# %%
# alternatively, drop rows that do not have a FIPS value
census_facility_no_na = census_facility[~census_facility['fips'].isna()]

# %%
census_facility_no_na
# Out:
#       FACILITY_ID   LATITUDE    LONGITUDE              CITY STATE    ZIP  \
# 0         1009051  37.795963  -122.022317         San Ramon    CA  94583
# 1         1008942   33.07567    -96.80594             Plano    TX  75024
# 2         1008914   32.75619    -97.33441        Fort Worth    TX  76102
# 3         1008688   32.00316   -102.07945           Midland    TX  79701
# 4         1008621   35.46734    -97.51406     Oklahoma City    OK  73102
# ...           ...        ...          ...               ...   ...    ...
# 9994      1009436  43.621474   -84.767905    Mount Pleasant    MI  48858
# 9996      1008897   42.45766    -83.65611        South Lyon    MI  48178
# 9998      1001085    39.4492     -84.4611           TRENTON    OH  45100
# 9999      1007870    28.4272     -81.5803  LAKE BUENA VISTA    FL  32830
# 10000     1001112    27.7886     -81.8694            BARTOW    FL  33830
#
#       COUNTY_FIPS           COUNTY                               ADDRESS1  \
# 0           06013     CONTRA COSTA             6001 Bollinger Canyon Road
# 1           48085           COLLIN                      5320 Legacy Drive
# 2           48439   TARRANT COUNTY            100 Throckmorton St., #1200
# 3           48329   MIDLAND COUNTY  600 North Marienfeld Street Suite 301
# 4           40109         Oklahoma                  333 West Sheridan Ave
# ...           ...              ...                                    ...
# 9994        26073  ISABELLA COUNTY                      1425 S Mission Rd
# 9996        26125   OAKLAND COUNTY                       400 South McMunn
# 9998        39017           Butler                      2100 WOODSDALE RD
# 9999        12095           Orange                 1375 Buena Vista Drive
# 10000       12105             Polk                   7700 COUNTY ROAD 555
#
#       ADDRESS2  ... UU_RD_EXEMPT REPORTING_STATUS PROCESS_STATIONARY_CML  \
# 0          NaN  ...          NaN              NaN                    NaN
# 1          NaN  ...          NaN              NaN                    NaN
# 2          NaN  ...          NaN              NaN                    NaN
# 3          NaN  ...          NaN              NaN                    NaN
# 4          NaN  ...          NaN              NaN                    NaN
# ...        ...  ...          ...              ...                    ...
# 9994       NaN  ...          NaN              NaN                    NaN
# 9996       NaN  ...          NaN              NaN                    NaN
# 9998       NaN  ...          NaN              NaN                    NaN
# 9999       NaN  ...          NaN              NaN                    NaN
# 10000      NaN  ...          NaN              NaN                    NaN
#
#       COMMENTS RR_MRV_PLAN_URL RR_MONITORING_PLAN_FILENAME  \
# 0          NaN             NaN                         NaN
# 1          NaN             NaN                         NaN
# 2          NaN             NaN                         NaN
# 3          NaN             NaN                         NaN
# 4          NaN             NaN                         NaN
# ...        ...             ...                         ...
# 9994       NaN             NaN                         NaN
# 9996       NaN             NaN                         NaN
# 9998       NaN             NaN                         NaN
# 9999       NaN             NaN                         NaN
# 10000      NaN             NaN                         NaN
#
#                                   name   fips population     mhi
# 0      Contra Costa County, California  06013    1147788  103997
# 1                 Collin County, Texas  48085    1006038  100541
# 2                Tarrant County, Texas  48439    2077153   70306
# 3                Midland County, Texas  48329     171238   83217
# 4            Oklahoma County, Oklahoma  40109     792668   55519
# ...                                ...    ...        ...     ...
# 9994         Isabella County, Michigan  26073      70363   46783
# 9996          Oakland County, Michigan  26125    1255340   81587
# 9998               Butler County, Ohio  39017     382129   69023
# 9999            Orange County, Florida  12095    1373784   61416
# 10000             Polk County, Florida  12105     705735   51535
#
# [9770 rows x 42 columns]

# %% [markdown]
# Notice that the number of rows for the inner join dataframe and the "no na" dataframe are the same! Checking the number of records throughout your transformation processes is a good way to quickly double check the transformations are successful and doing what you intended.

# %% [markdown]
# **Drop columns**

# %% [markdown]
# We saw how to select only the columns we want, but you can also drop columns. A lot of pandas functions have an "inplace" argument, which if set to *True* lets you avoid creating a whole new dataframe.

# %%
census_facility_inner.drop(columns=['ADDRESS1', 'ADDRESS2', 'COMMENTS', 'PROCESS_STATIONARY_CML',
                                   'RR_MRV_PLAN_URL', 'RR_MONITORING_PLAN_FILENAME'], inplace=True)

# %%
census_facility_inner.columns
# Out:
# Index(['FACILITY_ID', 'LATITUDE', 'LONGITUDE', 'CITY', 'STATE', 'ZIP',
#        'COUNTY_FIPS', 'COUNTY', 'FACILITY_NAME', 'STATE_NAME', 'NAICS_CODE',
#        'YEAR', 'BAMM_USED_DESC', 'EMISSION_CLASSIFICATION_CODE',
#        'PROGRAM_NAME', 'PROGRAM_SYS_ID', 'FRS_ID', 'CEMS_USED', 'CO2_CAPTURED',
#        'REPORTED_SUBPARTS', 'BAMM_APPROVED', 'EMITTED_CO2_SUPPLIED',
#        'TRIBAL_LAND_ID', 'EGGRT_FACILITY_ID', 'PUBLIC_XML', 'PARENT_COMPANY',
#        'PUBLIC_XML_XML', 'REPORTED_INDUSTRY_TYPES', 'FACILITY_TYPES',
#        'SUBMISSION_ID', 'UU_RD_EXEMPT', 'REPORTING_STATUS', 'name', 'fips',
#        'population', 'mhi'],
#       dtype='object')

# %% [markdown]
# When deciding whether to drop unnecessary or keep columns you want, it doesn't really matter so you'll typically just want to go with whichever is a shorter list. For example, it's easier to just drop a column or two than it is to select a whole bunch, and vice versa if you only need a couple of columns, it might be easier to just create a new dataframe that includes them, then trying to list out all the columns you want to drop.

# %%
census_facility = census_facility_inner[['FACILITY_ID','LATITUDE','LONGITUDE','CITY','ZIP',
                                   'COUNTY_FIPS','FACILITY_NAME',
                                   'YEAR','REPORTED_SUBPARTS','REPORTED_INDUSTRY_TYPES',
                                   'FACILITY_TYPES','name', 'population', 'mhi']]

# %% [markdown]
# **Aggregate total emissions for a facility for each year**
#
# Note: this transformations section got a little sketchy... made some assumptions for the sake of time and just demonstrating types of transformations, but in a real-world scenario we'd need to document those assumptions, and dig a little deeper to understand what's really happening to ensure our final results are correct

# %%
print(len(dataframes['join_sector_ghg']['FACILITY_ID'].unique()), len(census_facility.FACILITY_ID.unique()))
print(len(census_facility), len(dataframes['join_sector_ghg']))
print(census_facility.columns)
print(dataframes['join_sector_ghg'].columns)
# Out:
# 3291 5583
# 9770 10001
# Index(['FACILITY_ID', 'LATITUDE', 'LONGITUDE', 'CITY', 'ZIP', 'COUNTY_FIPS',
#        'FACILITY_NAME', 'YEAR', 'REPORTED_SUBPARTS', 'REPORTED_INDUSTRY_TYPES',
#        'FACILITY_TYPES', 'name', 'population', 'mhi'],
#       dtype='object')
# Index(['FACILITY_ID', 'YEAR', 'SECTOR_ID', 'SUBSECTOR_ID', 'GAS_ID',
#        'CO2E_EMISSION'],
#       dtype='object')

# %%
df = census_facility.merge(dataframes['join_sector_ghg'], how='inner', on=('FACILITY_ID', 'YEAR'))

# %%
df
# Out:
#     FACILITY_ID    LATITUDE     LONGITUDE                  CITY    ZIP  \
# 0       1003610   37.938779   -122.396453              RICHMOND  94801
# 1       1006843   33.774469   -118.290696            WILMINGTON  90744
# 2       1006629     33.8117    -118.16328            Long Beach  90806
# 3       1007870     28.4272      -81.5803      LAKE BUENA VISTA  32830
# 4       1006109   40.382251    -79.549157            Greensburg  15601
# ..          ...         ...           ...                   ...    ...
# 395     1005343   37.539714   -105.105336  LA VETA, 4.7 MI W OF  81055
# 396     1002001    39.20052     -83.59857             Hillsboro  45133
# 397     1003719  48.8743194  -102.5457778               Lignite  58752
# 398     1003719  48.8743194  -102.5457778               Lignite  58752
# 399     1005502    42.44311     -90.55686          EAST DUBUQUE  61025
#
#     COUNTY_FIPS                                      FACILITY_NAME  YEAR  \
# 0         06013                    CHEVRON PRODS.CO. RICHMOND REFY  2012
# 1         06037  Phillips 66 Los Angeles Refinery - Wilmington ...  2015
# 2         06037          City of Long Beach Gas and Oil Department  2016
# 3         12095  Reedy Creek Improvement District/Walt Disney W...  2018
# 4         42129                                            Delmont  2011
# ..          ...                                                ...   ...
# 395       08055                 Tabula Rasa Energy - LA VETA GAS P  2012
# 396       39071                           Pike Natural Gas Company  2016
# 397       38013                                  Lignite Gas Plant  2015
# 398       38013                                  Lignite Gas Plant  2015
# 399       17085             East Dubuque Nitrogen Fertilizers, LLC  2012
#
#     REPORTED_SUBPARTS REPORTED_INDUSTRY_TYPES            FACILITY_TYPES  \
# 0            C,P,PP,Y                C,P,PP,Y  Supplier, Direct Emitter
# 1            C,P,PP,Y                C,P,PP,Y  Supplier, Direct Emitter
# 2                  NN                  NN-LDC                  Supplier
# 3              C,D,NN              C,D,NN-LDC  Supplier, Direct Emitter
# 4                 C,W                C,W-NGTC            Direct Emitter
# ..                ...                     ...                       ...
# 395                PP                      PP                  Supplier
# 396                NN                  NN-LDC                  Supplier
# 397          NN,PP,UU           NN-FRAC,PP,UU   Supplier, CO2 Injection
# 398          NN,PP,UU           NN-FRAC,PP,UU   Supplier, CO2 Injection
# 399          C,G,PP,V                C,G,PP,V  Supplier, Direct Emitter
#
#                                   name population     mhi SECTOR_ID  \
# 0      Contra Costa County, California    1147788  103997        13
# 1       Los Angeles County, California   10040682   71358        13
# 2       Los Angeles County, California   10040682   71358        11
# 3               Orange County, Florida    1373784   61416        11
# 4    Westmoreland County, Pennsylvania     350722   61398        15
# ..                                 ...        ...     ...       ...
# 395          Huerfano County, Colorado       6769   40255        13
# 396              Highland County, Ohio      43080   47973        11
# 397         Burke County, North Dakota       2142   79405        11
# 398         Burke County, North Dakota       2142   79405        13
# 399        Jo Daviess County, Illinois      21429   59223        13
#
#     SUBSECTOR_ID GAS_ID CO2E_EMISSION
# 0             73    NaN           NaN
# 1             73    NaN           NaN
# 2             50      1      471075.5
# 3             50      1      105509.5
# 4             55      3        63.176
# ..           ...    ...           ...
# 395           74      1      237898.9
# 396           50      1       41735.8
# 397           51      1       99524.7
# 398           73    NaN           NaN
# 399           73    NaN           NaN
#
# [400 rows x 18 columns]

# %% [markdown]
# A lot less data than we'd expect... My guess looking at the model is facilities are *either* in subparts or sectors. If we were building out a pipeline we would probably have someone like a data scientist or business analyst who knows the data better than we do who could probably help guide the joins process better, or we'd want to investigate this further to see why so many facilities are left out of this join.

# %%
missing_facilities = []
for facility in dataframes['join_sector_ghg']['FACILITY_ID'].unique():
    if facility not in set(census_facility['FACILITY_ID']):
        missing_facilities.append(facility)

# %%
facilities = list(census_facility['FACILITY_ID'].unique())

# %%
missing_facilities.sort()
facilities.sort()

# %%
facilities
# Out:
# ['1000001',
#  '1000003',
#  '1000004',
#  '1000010',
#  '1000011',
#  '1000015',
#  '1000016',
#  '1000019',
#  '1000022',
#  '1000024',
#  '1000025',
#  '1000026',
#  '1000027',
#  '1000029',
#  '1000030',
#  '1000031',
#  '1000032',
#  '1000033',
#  '1000035',
#  '1000037',
#  '1000038',
#  '1000039',
#  '1000040',
#  '1000041',
#  '1000043',
#  '1000045',
#  '1000046',
#  '1000047',
#  '1000049',
#  '1000050',
#  '1000055',
#  '1000056',
#  '1000057',
#  '1000058',
#  '1000059',
#  '1000061',
#  '1000065',
#  '1000066',
#  '1000067',
#  '1000068',
#  '1000072',
#  '1000073',
#  '1000074',
#  '1000075',
#  '1000076',
#  '1000077',
#  '1000078',
#  '1000080',
#  '1000081',
#  '1000082',
#  '1000084',
#  '1000085',
#  '1000089',
#  '1000090',
#  '1000091',
#  '1000092',
#  '1000093',
#  '1000094',
#  '1000098',
#  '1000099',
#  '1000101',
#  '1000102',
#  '1000103',
#  '1000104',
#  '1000107',
#  '1000108',
#  '1000109',
#  '1000110',
#  '1000114',
#  '1000116',
#  '1000121',
#  '1000122',
#  '1000123',
#  '1000124',
#  '1000125',
#  '1000126',
#  '1000129',
#  '1000131',
#  '1000132',
#  '1000133',
#  '1000134',
#  '1000135',
#  '1000139',
#  '1000145',
#  '1000146',
#  '1000147',
#  '1000148',
#  '1000150',
#  '1000151',
#  '1000153',
#  '1000155',
#  '1000156',
#  '1000157',
#  '1000158',
#  '1000159',
#  '1000161',
#  '1000162',
#  '1000163',
#  '1000165',
#  '1000166',
#  '1000168',
#  '1000170',
#  '1000172',
#  '1000174',
#  '1000175',
#  '1000176',
#  '1000177',
#  '1000178',
#  '1000179',
#  '1000180',
#  '1000182',
#  '1000183',
#  '1000186',
#  '1000188',
#  '1000190',
#  '1000191',
#  '1000193',
#  '1000194',
#  '1000195',
#  '1000196',
#  '1000199',
#  '1000200',
#  '1000202',
#  '1000203',
#  '1000204',
#  '1000206',
#  '1000208',
#  '1000209',
#  '1000211',
#  '1000215',
#  '1000217',
#  '1000218',
#  '1000219',
#  '1000221',
#  '1000224',
#  '1000226',
#  '1000227',
#  '1000228',
#  '1000229',
#  '1000230',
#  '1000231',
#  '1000232',
#  '1000233',
#  '1000234',
#  '1000235',
#  '1000237',
#  '1000240',
#  '1000241',
#  '1000242',
#  '1000244',
#  '1000247',
#  '1000249',
#  '1000250',
#  '1000252',
#  '1000253',
#  '1000254',
#  '1000256',
#  '1000257',
#  '1000258',
#  '1000259',
#  '1000260',
#  '1000261',
#  '1000262',
#  '1000263',
#  '1000266',
#  '1000267',
#  '1000268',
#  '1000269',
#  '1000270',
#  '1000271',
#  '1000272',
#  '1000273',
#  '1000274',
#  '1000275',
#  '1000276',
#  '1000277',
#  '1000279',
#  '1000280',
#  '1000281',
#  '1000283',
#  '1000285',
#  '1000287',
#  '1000288',
#  '1000289',
#  '1000291',
#  '1000294',
#  '1000296',
#  '1000297',
#  '1000300',
#  '1000301',
#  '1000302',
#  '1000305',
#  '1000307',
#  '1000310',
#  '1000311',
#  '1000312',
#  '1000314',
#  '1000315',
#  '1000316',
#  '1000317',
#  '1000318',
#  '1000319',
#  '1000320',
#  '1000321',
#  '1000322',
#  '1000323',
#  '1000324',
#  '1000325',
#  '1000326',
#  '1000328',
#  '1000333',
#  '1000334',
#  '1000336',
#  '1000339',
#  '1000341',
#  '1000342',
#  '1000343',
#  '1000344',
#  '1000345',
#  '1000346',
#  '1000347',
#  '1000348',
#  '1000349',
#  '1000353',
#  '1000357',
#  '1000364',
#  '1000365',
#  '1000366',
#  '1000367',
#  '1000368',
#  '1000369',
#  '1000370',
#  '1000371',
#  '1000372',
#  '1000374',
#  '1000375',
#  '1000376',
#  '1000377',
#  '1000378',
#  '1000379',
#  '1000382',
#  '1000386',
#  '1000387',
#  '1000388',
#  '1000390',
#  '1000391',
#  '1000392',
#  '1000395',
#  '1000396',
#  '1000397',
#  '1000398',
#  '1000401',
#  '1000404',
#  '1000405',
#  '1000407',
#  '1000408',
#  '1000409',
#  '1000410',
#  '1000411',
#  '1000412',
#  '1000413',
#  '1000415',
#  '1000417',
#  '1000418',
#  '1000419',
#  '1000420',
#  '1000421',
#  '1000423',
#  '1000424',
#  '1000425',
#  '1000426',
#  '1000427',
#  '1000428',
#  '1000429',
#  '1000431',
#  '1000432',
#  '1000433',
#  '1000434',
#  '1000436',
#  '1000438',
#  '1000440',
#  '1000444',
#  '1000446',
#  '1000447',
#  '1000449',
#  '1000451',
#  '1000453',
#  '1000454',
#  '1000455',
#  '1000456',
#  '1000459',
#  '1000460',
#  '1000461',
#  '1000462',
#  '1000463',
#  '1000465',
#  '1000467',
#  '1000468',
#  '1000470',
#  '1000471',
#  '1000473',
#  '1000475',
#  '1000477',
#  '1000478',
#  '1000480',
#  '1000484',
#  '1000485',
#  '1000488',
#  '1000489',
#  '1000490',
#  '1000492',
#  '1000496',
#  '1000498',
#  '1000501',
#  '1000502',
#  '1000503',
#  '1000506',
#  '1000507',
#  '1000510',
#  '1000512',
#  '1000515',
#  '1000516',
#  '1000517',
#  '1000518',
#  '1000519',
#  '1000520',
#  '1000522',
#  '1000528',
#  '1000532',
#  '1000535',
#  '1000538',
#  '1000540',
#  '1000541',
#  '1000545',
#  '1000547',
#  '1000548',
#  '1000551',
#  '1000553',
#  '1000554',
#  '1000555',
#  '1000560',
#  '1000561',
#  '1000562',
#  '1000563',
#  '1000564',
#  '1000566',
#  '1000572',
#  '1000573',
#  '1000574',
#  '1000576',
#  '1000577',
#  '1000578',
#  '1000579',
#  '1000580',
#  '1000581',
#  '1000584',
#  '1000586',
#  '1000588',
#  '1000589',
#  '1000590',
#  '1000592',
#  '1000593',
#  '1000594',
#  '1000596',
#  '1000597',
#  '1000598',
#  '1000600',
#  '1000601',
#  '1000602',
#  '1000603',
#  '1000604',
#  '1000605',
#  '1000606',
#  '1000607',
#  '1000608',
#  '1000609',
#  '1000610',
#  '1000611',
#  '1000613',
#  '1000614',
#  '1000615',
#  '1000617',
#  '1000620',
#  '1000621',
#  '1000627',
#  '1000628',
#  '1000629',
#  '1000630',
#  '1000631',
#  '1000636',
#  '1000637',
#  '1000639',
#  '1000640',
#  '1000643',
#  '1000646',
#  '1000647',
#  '1000648',
#  '1000649',
#  '1000651',
#  '1000653',
#  '1000656',
#  '1000657',
#  '1000659',
#  '1000661',
#  '1000663',
#  '1000665',
#  '1000666',
#  '1000667',
#  '1000668',
#  '1000669',
#  '1000670',
#  '1000672',
#  '1000673',
#  '1000674',
#  '1000676',
#  '1000677',
#  '1000678',
#  '1000679',
#  '1000680',
#  '1000682',
#  '1000683',
#  '1000684',
#  '1000685',
#  '1000686',
#  '1000687',
#  '1000689',
#  '1000690',
#  '1000693',
#  '1000696',
#  '1000697',
#  '1000698',
#  '1000700',
#  '1000701',
#  '1000702',
#  '1000703',
#  '1000706',
#  '1000709',
#  '1000711',
#  '1000712',
#  '1000713',
#  '1000715',
#  '1000716',
#  '1000717',
#  '1000718',
#  '1000720',
#  '1000721',
#  '1000722',
#  '1000725',
#  '1000726',
#  '1000727',
#  '1000732',
#  '1000733',
#  '1000734',
#  '1000735',
#  '1000737',
#  '1000738',
#  '1000740',
#  '1000741',
#  '1000742',
#  '1000743',
#  '1000744',
#  '1000745',
#  '1000747',
#  '1000750',
#  '1000753',
#  '1000758',
#  '1000760',
#  '1000762',
#  '1000763',
#  '1000764',
#  '1000766',
#  '1000768',
#  '1000770',
#  '1000771',
#  '1000772',
#  '1000773',
#  '1000778',
#  '1000779',
#  '1000780',
#  '1000781',
#  '1000783',
#  '1000785',
#  '1000786',
#  '1000787',
#  '1000788',
#  '1000790',
#  '1000793',
#  '1000796',
#  '1000798',
#  '1000800',
#  '1000801',
#  '1000806',
#  '1000807',
#  '1000812',
#  '1000813',
#  '1000815',
#  '1000818',
#  '1000819',
#  '1000820',
#  '1000823',
#  '1000826',
#  '1000828',
#  '1000829',
#  '1000830',
#  '1000831',
#  '1000833',
#  '1000835',
#  '1000836',
#  '1000841',
#  '1000843',
#  '1000844',
#  '1000846',
#  '1000848',
#  '1000849',
#  '1000850',
#  '1000851',
#  '1000852',
#  '1000853',
#  '1000855',
#  '1000856',
#  '1000859',
#  '1000862',
#  '1000864',
#  '1000865',
#  '1000867',
#  '1000868',
#  '1000873',
#  '1000875',
#  '1000877',
#  '1000878',
#  '1000879',
#  '1000880',
#  '1000881',
#  '1000883',
#  '1000884',
#  '1000886',
#  '1000890',
#  '1000891',
#  '1000892',
#  '1000893',
#  '1000896',
#  '1000898',
#  '1000901',
#  '1000902',
#  '1000906',
#  '1000908',
#  '1000910',
#  '1000912',
#  '1000913',
#  '1000914',
#  '1000916',
#  '1000917',
#  '1000919',
#  '1000922',
#  '1000935',
#  '1000936',
#  '1000938',
#  '1000941',
#  '1000948',
#  '1000952',
#  '1000953',
#  '1000954',
#  '1000955',
#  '1000956',
#  '1000960',
#  '1000962',
#  '1000964',
#  '1000965',
#  '1000966',
#  '1000967',
#  '1000968',
#  '1000969',
#  '1000970',
#  '1000971',
#  '1000972',
#  '1000973',
#  '1000974',
#  '1000975',
#  '1000979',
#  '1000983',
#  '1000984',
#  '1000985',
#  '1000986',
#  '1000988',
#  '1000989',
#  '1000991',
#  '1000993',
#  '1000994',
#  '1000996',
#  '1001003',
#  '1001006',
#  '1001008',
#  '1001011',
#  '1001012',
#  '1001013',
#  '1001014',
#  '1001015',
#  '1001017',
#  '1001018',
#  '1001021',
#  '1001022',
#  '1001023',
#  '1001025',
#  '1001029',
#  '1001031',
#  '1001032',
#  '1001037',
#  '1001038',
#  '1001039',
#  '1001040',
#  '1001041',
#  '1001042',
#  '1001044',
#  '1001047',
#  '1001049',
#  '1001051',
#  '1001052',
#  '1001053',
#  '1001055',
#  '1001056',
#  '1001058',
#  '1001060',
#  '1001061',
#  '1001063',
#  '1001064',
#  '1001065',
#  '1001067',
#  '1001070',
#  '1001072',
#  '1001076',
#  '1001080',
#  '1001083',
#  '1001085',
#  '1001087',
#  '1001088',
#  '1001091',
#  '1001093',
#  '1001098',
#  '1001101',
#  '1001102',
#  '1001104',
#  '1001105',
#  '1001106',
#  '1001109',
#  '1001110',
#  '1001112',
#  '1001113',
#  '1001114',
#  '1001115',
#  '1001116',
#  '1001118',
#  '1001121',
#  '1001122',
#  '1001123',
#  '1001126',
#  '1001127',
#  '1001132',
#  '1001133',
#  '1001134',
#  '1001135',
#  '1001137',
#  '1001141',
#  '1001142',
#  '1001144',
#  '1001145',
#  '1001146',
#  '1001147',
#  '1001149',
#  '1001150',
#  '1001151',
#  '1001152',
#  '1001153',
#  '1001158',
#  '1001161',
#  '1001164',
#  '1001165',
#  '1001166',
#  '1001167',
#  '1001168',
#  '1001169',
#  '1001170',
#  '1001172',
#  '1001176',
#  '1001178',
#  '1001180',
#  '1001183',
#  '1001184',
#  '1001188',
#  '1001191',
#  '1001193',
#  '1001194',
#  '1001195',
#  '1001197',
#  '1001199',
#  '1001200',
#  '1001201',
#  '1001204',
#  '1001207',
#  '1001208',
#  '1001210',
#  '1001211',
#  '1001212',
#  '1001214',
#  '1001215',
#  '1001216',
#  '1001219',
#  '1001220',
#  '1001221',
#  '1001222',
#  '1001224',
#  '1001225',
#  '1001227',
#  '1001228',
#  '1001229',
#  '1001230',
#  '1001231',
#  '1001234',
#  '1001235',
#  '1001236',
#  '1001237',
#  '1001241',
#  '1001244',
#  '1001245',
#  '1001246',
#  '1001248',
#  '1001249',
#  '1001250',
#  '1001251',
#  '1001252',
#  '1001254',
#  '1001258',
#  '1001259',
#  '1001261',
#  '1001262',
#  '1001263',
#  '1001266',
#  '1001270',
#  '1001271',
#  '1001273',
#  '1001274',
#  '1001275',
#  '1001276',
#  '1001277',
#  '1001280',
#  '1001281',
#  '1001286',
#  '1001287',
#  '1001288',
#  '1001289',
#  '1001294',
#  '1001295',
#  '1001299',
#  '1001301',
#  '1001302',
#  '1001305',
#  '1001306',
#  '1001307',
#  '1001311',
#  '1001313',
#  '1001315',
#  '1001317',
#  '1001320',
#  '1001321',
#  '1001324',
#  '1001325',
#  '1001329',
#  '1001330',
#  '1001333',
#  '1001334',
#  '1001336',
#  '1001338',
#  '1001340',
#  '1001342',
#  '1001343',
#  '1001344',
#  '1001345',
#  '1001346',
#  '1001348',
#  '1001351',
#  '1001353',
#  '1001354',
#  '1001355',
#  '1001356',
#  '1001357',
#  '1001359',
#  '1001360',
#  '1001362',
#  '1001367',
#  '1001369',
#  '1001370',
#  '1001372',
#  '1001374',
#  '1001375',
#  '1001376',
#  '1001377',
#  '1001378',
#  '1001381',
#  '1001382',
#  '1001385',
#  '1001386',
#  '1001387',
#  '1001388',
#  '1001390',
#  '1001391',
#  '1001393',
#  '1001396',
#  '1001397',
#  '1001398',
#  '1001399',
#  '1001401',
#  '1001403',
#  '1001404',
#  '1001405',
#  '1001406',
#  '1001407',
#  '1001409',
#  '1001410',
#  '1001411',
#  '1001412',
#  '1001414',
#  '1001415',
#  '1001416',
#  '1001417',
#  '1001418',
#  '1001421',
#  '1001422',
#  '1001424',
#  '1001425',
#  '1001426',
#  '1001427',
#  '1001429',
#  '1001430',
#  '1001431',
#  '1001433',
#  '1001434',
#  '1001438',
#  '1001439',
#  '1001440',
#  '1001441',
#  '1001442',
#  '1001444',
#  '1001445',
#  '1001447',
#  '1001448',
#  '1001451',
#  '1001453',
#  '1001454',
#  '1001456',
#  '1001459',
#  '1001460',
#  '1001461',
#  '1001462',
#  '1001463',
#  '1001464',
#  '1001465',
#  '1001466',
#  '1001469',
#  '1001470',
#  '1001472',
#  '1001474',
#  '1001475',
#  '1001477',
#  '1001480',
#  '1001481',
#  '1001482',
#  '1001483',
#  '1001484',
#  '1001485',
#  '1001487',
#  '1001489',
#  '1001490',
#  '1001495',
#  '1001496',
#  '1001497',
#  '1001498',
#  '1001500',
#  '1001501',
#  '1001502',
#  '1001505',
#  '1001506',
#  '1001507',
#  '1001508',
#  '1001509',
#  '1001510',
#  '1001516',
#  '1001517',
#  '1001518',
#  '1001519',
#  '1001520',
#  '1001524',
#  '1001526',
#  '1001527',
#  '1001530',
#  '1001531',
#  '1001532',
#  '1001533',
#  '1001534',
#  '1001535',
#  '1001536',
#  '1001541',
#  '1001543',
#  '1001545',
#  '1001548',
#  '1001549',
#  '1001550',
#  '1001551',
#  '1001552',
#  '1001553',
#  '1001556',
#  '1001557',
#  '1001563',
#  '1001564',
#  '1001567',
#  '1001568',
#  '1001569',
#  '1001571',
#  '1001573',
#  '1001574',
#  '1001576',
#  '1001577',
#  '1001578',
#  '1001581',
#  '1001582',
#  '1001583',
#  '1001584',
#  '1001586',
#  '1001587',
#  '1001589',
#  '1001590',
#  '1001595',
#  '1001598',
#  '1001600',
#  '1001601',
#  '1001603',
#  '1001607',
#  '1001608',
#  '1001609',
#  '1001610',
#  '1001612',
#  '1001613',
#  '1001614',
#  '1001617',
#  '1001619',
#  '1001620',
#  '1001621',
#  '1001622',
#  '1001623',
#  '1001624',
#  '1001625',
#  '1001626',
#  '1001627',
#  '1001628',
#  '1001629',
#  '1001630',
#  '1001631',
#  '1001632',
#  '1001633',
#  '1001635',
#  '1001636',
#  '1001637',
#  '1001638',
#  '1001639',
#  '1001640',
#  '1001641',
#  '1001642',
#  '1001643',
#  '1001645',
#  '1001649',
#  '1001650',
#  '1001652',
#  '1001653',
#  '1001654',
#  '1001655',
#  '1001656',
#  '1001657',
#  '1001658',
#  '1001659',
#  '1001660',
#  '1001661',
#  '1001662',
#  '1001664',
#  '1001665',
#  '1001667',
#  '1001668',
#  '1001669',
#  '1001671',
#  '1001674',
#  '1001676',
#  '1001677',
#  '1001678',
#  '1001680',
#  '1001681',
#  '1001683',
#  '1001685',
#  '1001686',
#  '1001691',
#  '1001696',
#  '1001697',
#  '1001698',
#  '1001699',
#  ...]

# %%
missing_facilities
# Out:
# ['1000002',
#  '1000005',
#  '1000006',
#  '1000008',
#  '1000020',
#  '1000021',
#  '1000023',
#  '1000028',
#  '1000051',
#  '1000052',
#  '1000054',
#  '1000060',
#  '1000064',
#  '1000069',
#  '1000070',
#  '1000071',
#  '1000083',
#  '1000086',
#  '1000087',
#  '1000095',
#  '1000096',
#  '1000097',
#  '1000100',
#  '1000105',
#  '1000106',
#  '1000111',
#  '1000112',
#  '1000113',
#  '1000117',
#  '1000118',
#  '1000119',
#  '1000120',
#  '1000127',
#  '1000128',
#  '1000130',
#  '1000136',
#  '1000137',
#  '1000138',
#  '1000141',
#  '1000144',
#  '1000152',
#  '1000169',
#  '1000205',
#  '1000213',
#  '1000245',
#  '1000292',
#  '1000335',
#  '1000350',
#  '1000355',
#  '1000381',
#  '1000435',
#  '1000439',
#  '1000479',
#  '1000529',
#  '1000530',
#  '1000531',
#  '1000533',
#  '1000536',
#  '1000539',
#  '1000542',
#  '1000544',
#  '1000546',
#  '1000550',
#  '1000552',
#  '1000558',
#  '1000559',
#  '1000565',
#  '1000569',
#  '1000797',
#  '1000803',
#  '1000842',
#  '1000854',
#  '1000857',
#  '1000869',
#  '1000872',
#  '1000894',
#  '1000900',
#  '1000903',
#  '1000904',
#  '1000907',
#  '1001057',
#  '1001068',
#  '1001069',
#  '1001071',
#  '1001073',
#  '1001074',
#  '1001078',
#  '1001081',
#  '1001089',
#  '1001090',
#  '1001120',
#  '1001139',
#  '1001143',
#  '1001155',
#  '1001157',
#  '1001223',
#  '1001267',
#  '1001290',
#  '1001293',
#  '1001316',
#  '1001389',
#  '1001395',
#  '1001402',
#  '1001437',
#  '1001537',
#  '1001555',
#  '1001558',
#  '1001559',
#  '1001560',
#  '1001562',
#  '1001588',
#  '1001634',
#  '1001644',
#  '1001646',
#  '1001651',
#  '1001663',
#  '1001666',
#  '1001670',
#  '1001672',
#  '1001675',
#  '1001679',
#  '1001688',
#  '1001712',
#  '1001717',
#  '1001719',
#  '1001723',
#  '1001727',
#  '1001728',
#  '1001732',
#  '1001736',
#  '1001741',
#  '1001742',
#  '1001748',
#  '1001751',
#  '1001765',
#  '1001771',
#  '1001776',
#  '1001777',
#  '1001778',
#  '1001779',
#  '1001780',
#  '1001801',
#  '1001802',
#  '1001811',
#  '1001813',
#  '1001814',
#  '1001817',
#  '1001818',
#  '1001828',
#  '1001832',
#  '1001841',
#  '1001842',
#  '1001860',
#  '1001865',
#  '1001870',
#  '1001882',
#  '1001893',
#  '1001905',
#  '1001910',
#  '1001921',
#  '1001934',
#  '1001954',
#  '1001962',
#  '1001978',
#  '1002037',
#  '1002092',
#  '1002129',
#  '1002131',
#  '1002139',
#  '1002143',
#  '1002145',
#  '1002147',
#  '1002171',
#  '1002180',
#  '1002188',
#  '1002191',
#  '1002192',
#  '1002216',
#  '1002226',
#  '1002231',
#  '1002261',
#  '1002265',
#  '1002290',
#  '1002292',
#  '1002344',
#  '1002358',
#  '1002362',
#  '1002366',
#  '1002367',
#  '1002384',
#  '1002396',
#  '1002403',
#  '1002405',
#  '1002424',
#  '1002430',
#  '1002439',
#  '1002481',
#  '1002499',
#  '1002504',
#  '1002506',
#  '1002507',
#  '1002517',
#  '1002518',
#  '1002519',
#  '1002522',
#  '1002527',
#  '1002537',
#  '1002538',
#  '1002551',
#  '1002562',
#  '1002568',
#  '1002569',
#  '1002576',
#  '1002589',
#  '1002608',
#  '1002620',
#  '1002621',
#  '1002636',
#  '1002665',
#  '1002675',
#  '1002679',
#  '1002681',
#  '1002684',
#  '1002685',
#  '1002688',
#  '1002690',
#  '1002698',
#  '1002727',
#  '1002763',
#  '1002764',
#  '1002768',
#  '1002769',
#  '1002770',
#  '1002774',
#  '1002777',
#  '1002790',
#  '1002793',
#  '1002794',
#  '1002798',
#  '1002801',
#  '1002837',
#  '1002842',
#  '1002864',
#  '1002867',
#  '1002889',
#  '1002905',
#  '1002907',
#  '1002915',
#  '1002919',
#  '1002923',
#  '1002924',
#  '1002929',
#  '1002934',
#  '1002950',
#  '1002958',
#  '1002969',
#  '1002970',
#  '1002974',
#  '1002977',
#  '1002998',
#  '1003023',
#  '1003026',
#  '1003030',
#  '1003041',
#  '1003043',
#  '1003045',
#  '1003052',
#  '1003056',
#  '1003062',
#  '1003068',
#  '1003069',
#  '1003074',
#  '1003077',
#  '1003100',
#  '1003127',
#  '1003130',
#  '1003134',
#  '1003144',
#  '1003152',
#  '1003154',
#  '1003177',
#  '1003188',
#  '1003204',
#  '1003223',
#  '1003228',
#  '1003245',
#  '1003255',
#  '1003258',
#  '1003268',
#  '1003279',
#  '1003287',
#  '1003292',
#  '1003298',
#  '1003308',
#  '1003311',
#  '1003326',
#  '1003336',
#  '1003345',
#  '1003348',
#  '1003352',
#  '1003360',
#  '1003364',
#  '1003395',
#  '1003399',
#  '1003403',
#  '1003423',
#  '1003435',
#  '1003443',
#  '1003447',
#  '1003457',
#  '1003462',
#  '1003465',
#  '1003474',
#  '1003475',
#  '1003479',
#  '1003487',
#  '1003489',
#  '1003507',
#  '1003508',
#  '1003515',
#  '1003520',
#  '1003525',
#  '1003529',
#  '1003534',
#  '1003545',
#  '1003552',
#  '1003554',
#  '1003555',
#  '1003556',
#  '1003559',
#  '1003572',
#  '1003578',
#  '1003580',
#  '1003590',
#  '1003600',
#  '1003605',
#  '1003624',
#  '1003627',
#  '1003636',
#  '1003656',
#  '1003657',
#  '1003668',
#  '1003669',
#  '1003670',
#  '1003688',
#  '1003691',
#  '1003692',
#  '1003699',
#  '1003716',
#  '1003717',
#  '1003725',
#  '1003726',
#  '1003729',
#  '1003734',
#  '1003739',
#  '1003754',
#  '1003762',
#  '1003767',
#  '1003774',
#  '1003777',
#  '1003794',
#  '1003799',
#  '1003838',
#  '1003849',
#  '1003860',
#  '1003867',
#  '1003890',
#  '1003899',
#  '1003911',
#  '1003915',
#  '1003917',
#  '1003942',
#  '1003951',
#  '1003961',
#  '1003965',
#  '1003968',
#  '1003981',
#  '1003993',
#  '1003999',
#  '1004000',
#  '1004012',
#  '1004020',
#  '1004026',
#  '1004032',
#  '1004037',
#  '1004038',
#  '1004047',
#  '1004062',
#  '1004071',
#  '1004074',
#  '1004081',
#  '1004085',
#  '1004087',
#  '1004091',
#  '1004095',
#  '1004103',
#  '1004109',
#  '1004110',
#  '1004114',
#  '1004123',
#  '1004143',
#  '1004152',
#  '1004161',
#  '1004163',
#  '1004167',
#  '1004168',
#  '1004174',
#  '1004183',
#  '1004184',
#  '1004187',
#  '1004197',
#  '1004200',
#  '1004207',
#  '1004208',
#  '1004213',
#  '1004215',
#  '1004225',
#  '1004228',
#  '1004230',
#  '1004233',
#  '1004236',
#  '1004248',
#  '1004258',
#  '1004259',
#  '1004272',
#  '1004285',
#  '1004296',
#  '1004300',
#  '1004301',
#  '1004302',
#  '1004321',
#  '1004341',
#  '1004344',
#  '1004345',
#  '1004362',
#  '1004376',
#  '1004386',
#  '1004387',
#  '1004391',
#  '1004394',
#  '1004400',
#  '1004404',
#  '1004411',
#  '1004418',
#  '1004427',
#  '1004434',
#  '1004436',
#  '1004450',
#  '1004453',
#  '1004458',
#  '1004476',
#  '1004477',
#  '1004484',
#  '1004486',
#  '1004493',
#  '1004494',
#  '1004499',
#  '1004507',
#  '1004509',
#  '1004511',
#  '1004512',
#  '1004524',
#  '1004527',
#  '1004532',
#  '1004543',
#  '1004550',
#  '1004557',
#  '1004567',
#  '1004573',
#  '1004574',
#  '1004582',
#  '1004583',
#  '1004592',
#  '1004593',
#  '1004600',
#  '1004602',
#  '1004603',
#  '1004608',
#  '1004613',
#  '1004614',
#  '1004616',
#  '1004620',
#  '1004622',
#  '1004631',
#  '1004632',
#  '1004652',
#  '1004660',
#  '1004663',
#  '1004667',
#  '1004669',
#  '1004670',
#  '1004689',
#  '1004696',
#  '1004703',
#  '1004711',
#  '1004715',
#  '1004723',
#  '1004724',
#  '1004727',
#  '1004729',
#  '1004743',
#  '1004746',
#  '1004751',
#  '1004755',
#  '1004761',
#  '1004773',
#  '1004779',
#  '1004782',
#  '1004786',
#  '1004811',
#  '1004813',
#  '1004818',
#  '1004843',
#  '1004844',
#  '1004852',
#  '1004858',
#  '1004874',
#  '1004894',
#  '1004902',
#  '1004903',
#  '1004910',
#  '1004916',
#  '1004922',
#  '1004923',
#  '1004924',
#  '1004926',
#  '1004928',
#  '1004934',
#  '1004938',
#  '1004941',
#  '1004942',
#  '1004943',
#  '1004946',
#  '1004954',
#  '1004962',
#  '1004970',
#  '1004973',
#  '1004984',
#  '1004997',
#  '1005002',
#  '1005003',
#  '1005007',
#  '1005018',
#  '1005031',
#  '1005035',
#  '1005060',
#  '1005062',
#  '1005074',
#  '1005079',
#  '1005113',
#  '1005116',
#  '1005121',
#  '1005122',
#  '1005126',
#  '1005143',
#  '1005144',
#  '1005158',
#  '1005159',
#  '1005160',
#  '1005161',
#  '1005163',
#  '1005165',
#  '1005168',
#  '1005190',
#  '1005201',
#  '1005202',
#  '1005215',
#  '1005217',
#  '1005235',
#  '1005237',
#  '1005256',
#  '1005258',
#  '1005259',
#  '1005276',
#  '1005283',
#  '1005285',
#  '1005291',
#  '1005294',
#  '1005298',
#  '1005301',
#  '1005329',
#  '1005332',
#  '1005335',
#  '1005344',
#  '1005346',
#  '1005358',
#  '1005381',
#  '1005388',
#  '1005410',
#  '1005420',
#  '1005426',
#  '1005431',
#  '1005435',
#  '1005436',
#  '1005465',
#  '1005477',
#  '1005483',
#  '1005506',
#  '1005514',
#  '1005515',
#  '1005516',
#  '1005519',
#  '1005530',
#  '1005536',
#  '1005537',
#  '1005558',
#  '1005568',
#  '1005569',
#  '1005570',
#  '1005572',
#  '1005573',
#  '1005576',
#  '1005584',
#  '1005598',
#  '1005599',
#  '1005602',
#  '1005608',
#  '1005634',
#  '1005652',
#  '1005663',
#  '1005700',
#  '1005701',
#  '1005707',
#  '1005715',
#  '1005726',
#  '1005729',
#  '1005736',
#  '1005745',
#  '1005752',
#  '1005759',
#  '1005761',
#  '1005764',
#  '1005777',
#  '1005787',
#  '1005788',
#  '1005801',
#  '1005806',
#  '1005814',
#  '1005836',
#  '1005846',
#  '1005857',
#  '1005865',
#  '1005876',
#  '1005883',
#  '1005884',
#  '1005906',
#  '1005910',
#  '1005914',
#  '1005915',
#  '1005925',
#  '1005928',
#  '1005944',
#  '1005958',
#  '1005960',
#  '1005977',
#  '1006021',
#  '1006029',
#  '1006032',
#  '1006036',
#  '1006050',
#  '1006053',
#  '1006060',
#  '1006074',
#  '1006096',
#  '1006099',
#  '1006111',
#  '1006138',
#  '1006151',
#  '1006152',
#  '1006154',
#  '1006156',
#  '1006160',
#  '1006164',
#  '1006170',
#  '1006174',
#  '1006230',
#  '1006244',
#  '1006260',
#  '1006269',
#  '1006270',
#  '1006272',
#  '1006300',
#  '1006325',
#  '1006332',
#  '1006341',
#  '1006343',
#  '1006351',
#  '1006354',
#  '1006358',
#  '1006363',
#  '1006375',
#  '1006382',
#  '1006383',
#  '1006386',
#  '1006398',
#  '1006424',
#  '1006429',
#  '1006434',
#  '1006440',
#  '1006456',
#  '1006458',
#  '1006467',
#  '1006472',
#  '1006481',
#  '1006483',
#  '1006486',
#  '1006497',
#  '1006530',
#  '1006550',
#  '1006551',
#  '1006562',
#  '1006564',
#  '1006567',
#  '1006579',
#  '1006585',
#  '1006599',
#  '1006627',
#  '1006640',
#  '1006657',
#  '1006666',
#  '1006675',
#  '1006688',
#  '1006689',
#  '1006696',
#  '1006716',
#  '1006730',
#  '1006738',
#  '1006739',
#  '1006740',
#  '1006755',
#  '1006758',
#  '1006763',
#  '1006769',
#  '1006770',
#  '1006771',
#  '1006784',
#  '1006793',
#  '1006797',
#  '1006801',
#  '1006810',
#  '1006813',
#  '1006819',
#  '1006825',
#  '1006826',
#  '1006827',
#  '1006829',
#  '1006836',
#  '1006839',
#  '1006846',
#  '1006847',
#  '1006853',
#  '1006856',
#  '1006861',
#  '1006863',
#  '1006865',
#  '1006872',
#  '1006873',
#  '1006879',
#  '1006880',
#  '1006890',
#  '1006896',
#  '1006901',
#  '1006902',
#  '1006904',
#  '1006906',
#  '1006908',
#  '1006910',
#  '1006912',
#  '1006914',
#  '1006917',
#  '1006925',
#  '1006942',
#  '1006974',
#  '1006992',
#  '1007004',
#  '1007005',
#  '1007006',
#  '1007020',
#  '1007021',
#  '1007037',
#  '1007042',
#  '1007046',
#  '1007048',
#  '1007066',
#  '1007071',
#  '1007093',
#  '1007104',
#  '1007107',
#  '1007113',
#  '1007120',
#  '1007125',
#  '1007136',
#  '1007199',
#  '1007281',
#  '1007288',
#  '1007356',
#  '1007361',
#  '1007368',
#  '1007393',
#  '1007403',
#  '1007430',
#  '1007441',
#  '1007482',
#  '1007484',
#  '1007485',
#  '1007486',
#  '1007487',
#  '1007496',
#  '1007530',
#  '1007536',
#  '1007568',
#  '1007572',
#  '1007747',
#  '1007777',
#  '1007779',
#  '1007781',
#  '1007787',
#  '1007809',
#  '1007828',
#  '1007830',
#  '1007849',
#  '1007872',
#  '1007939',
#  '1007974',
#  '1007978',
#  '1007985',
#  '1008002',
#  '1008026',
#  '1008035',
#  '1008046',
#  '1008051',
#  '1008053',
#  '1008055',
#  '1008062',
#  '1008066',
#  '1008078',
#  '1008080',
#  '1008081',
#  '1008086',
#  '1008087',
#  '1008090',
#  '1008092',
#  '1008093',
#  '1008098',
#  '1008119',
#  '1008123',
#  '1008126',
#  '1008134',
#  '1008141',
#  '1008151',
#  '1008158',
#  '1008160',
#  '1008162',
#  '1008163',
#  '1008165',
#  '1008167',
#  '1008170',
#  '1008172',
#  '1008173',
#  '1008190',
#  '1008200',
#  '1008202',
#  '1008206',
#  '1008216',
#  '1008219',
#  '1008224',
#  '1008226',
#  '1008234',
#  '1008238',
#  '1008239',
#  '1008240',
#  '1008241',
#  '1008242',
#  '1008247',
#  '1008249',
#  '1008250',
#  '1008264',
#  '1008267',
#  '1008270',
#  '1008275',
#  '1008277',
#  '1008281',
#  '1008282',
#  '1008286',
#  '1008290',
#  '1008293',
#  '1008504',
#  '1008579',
#  '1008588',
#  '1008590',
#  '1008595',
#  '1008605',
#  '1008607',
#  '1008616',
#  '1008617',
#  '1008622',
#  '1008630',
#  '1008632',
#  '1008642',
#  '1008652',
#  '1008670',
#  '1008673',
#  '1008677',
#  '1008680',
#  '1008681',
#  '1008685',
#  '1008700',
#  '1008702',
#  '1008703',
#  '1008714',
#  '1008715',
#  '1008724',
#  '1008731',
#  '1008735',
#  '1008740',
#  '1008753',
#  '1008755',
#  '1008760',
#  '1008761',
#  '1008764',
#  '1008773',
#  '1008783',
#  '1008784',
#  '1008794',
#  '1008795',
#  '1008806',
#  '1008809',
#  '1008826',
#  '1008827',
#  '1008829',
#  '1008831',
#  '1008835',
#  '1008836',
#  '1008852',
#  '1008857',
#  '1008885',
#  '1008920',
#  '1008921',
#  '1008932',
#  '1008933',
#  '1008937',
#  '1008941',
#  '1008943',
#  '1008954',
#  '1008956',
#  '1008957',
#  '1008969',
#  '1008970',
#  '1008976',
#  '1008977',
#  '1008980',
#  '1008982',
#  '1009006',
#  '1009017',
#  '1009019',
#  '1009056',
#  '1009071',
#  '1009082',
#  '1009085',
#  '1009091',
#  '1009098',
#  '1009101',
#  '1009103',
#  '1009106',
#  '1009113',
#  '1009115',
#  '1009125',
#  '1009126',
#  '1009130',
#  '1009141',
#  '1009143',
#  '1009151',
#  '1009152',
#  '1009154',
#  '1009161',
#  '1009165',
#  '1009179',
#  '1009185',
#  '1009197',
#  '1009203',
#  '1009205',
#  '1009206',
#  '1009215',
#  '1009233',
#  '1009234',
#  '1009236',
#  '1009238',
#  '1009239',
#  '1009240',
#  '1009242',
#  '1009244',
#  '1009253',
#  '1009258',
#  '1009260',
#  '1009261',
#  '1009264',
#  '1009265',
#  '1009274',
#  '1009276',
#  '1009278',
#  ...]

# %% [markdown]
# Digging in a little further, for this dataset having a "year" for the facility just leads to duplicates. For our case we just want one row per facility, if they're name changed, or anything like that it doesn't really matter for us. **THIS IS A MAJOR ASSUMPTION**.
#
#
# NOTE: An extension of this exercise could be pulling census data from multiple years, to have a more robust representation of the population, mhi, etc. for a given point in time.

# %% [markdown]
# This was some tricky python! Couldn't just use regular groupby, because we lost the indicies. Here's the stackoverflow post I used: https://stackoverflow.com/questions/15705630/get-the-rows-which-have-the-max-value-in-groups-using-groupby

# %%
max_year = census_facility.groupby('FACILITY_ID')['YEAR'].transform(max) == census_facility['YEAR']
unique_facilities = census_facility[max_year].drop(columns=['YEAR'])

# %%
len(census_facility.FACILITY_ID.unique())
# Out:
# 5583

# %%
len(unique_facilities)
# Out:
# 5583

# %%
df = unique_facilities.merge(dataframes['join_sector_ghg'], how='inner', on='FACILITY_ID')

# %%
df
# Out:
#      FACILITY_ID   LATITUDE   LONGITUDE            CITY    ZIP COUNTY_FIPS  \
# 0        1007390    38.0251   -122.0639        MARTINEZ  94553       06013
# 1        1007390    38.0251   -122.0639        MARTINEZ  94553       06013
# 2        1007390    38.0251   -122.0639        MARTINEZ  94553       06013
# 3        1008961   37.75832  -121.95969       San Ramon  94583       06013
# 4        1008961   37.75832  -121.95969       San Ramon  94583       06013
# ...          ...        ...         ...             ...    ...         ...
# 6133     1000855    41.4514     -97.095        SCHUYLER  68661       31037
# 6134     1010242    36.8358    -83.0331     St. Charles  24282       51105
# 6135     1009436  43.621474  -84.767905  Mount Pleasant  48858       26073
# 6136     1009436  43.621474  -84.767905  Mount Pleasant  48858       26073
# 6137     1009436  43.621474  -84.767905  Mount Pleasant  48858       26073
#
#                                           FACILITY_NAME REPORTED_SUBPARTS  \
# 0     TESORO REFINING AND MARKETING COMPANY GOLDEN E...          C,P,PP,Y
# 1     TESORO REFINING AND MARKETING COMPANY GOLDEN E...          C,P,PP,Y
# 2     TESORO REFINING AND MARKETING COMPANY GOLDEN E...          C,P,PP,Y
# 3                      Chevron MCA 220 Gulf Coast Basin               NaN
# 4                      Chevron MCA 220 Gulf Coast Basin               NaN
# ...                                                 ...               ...
# 6133                 Cargill Meat Solutions Corporation              C,II
# 6134                     Lone Mountain Processing, Inc.              C,FF
# 6135                       Muskegon Development Company                 W
# 6136                       Muskegon Development Company                 W
# 6137                       Muskegon Development Company                 W
#
#      REPORTED_INDUSTRY_TYPES                FACILITY_TYPES  \
# 0                   C,P,PP,Y      Supplier, Direct Emitter
# 1                   C,P,PP,Y      Supplier, Direct Emitter
# 2                   C,P,PP,Y      Supplier, Direct Emitter
# 3                        NaN                           NaN
# 4                        NaN                           NaN
# ...                      ...                           ...
# 6133                    C,II                Direct Emitter
# 6134                    C,FF                Direct Emitter
# 6135                  W-ONSH  Onshore Oil & Gas Production
# 6136                  W-ONSH  Onshore Oil & Gas Production
# 6137                  W-ONSH  Onshore Oil & Gas Production
#
#                                  name population     mhi  YEAR SECTOR_ID  \
# 0     Contra Costa County, California    1147788  103997  2015        13
# 1     Contra Costa County, California    1147788  103997  2012        13
# 2     Contra Costa County, California    1147788  103997  2014        13
# 3     Contra Costa County, California    1147788  103997  2014        15
# 4     Contra Costa County, California    1147788  103997  2014        15
# ...                               ...        ...     ...   ...       ...
# 6133          Colfax County, Nebraska      10681   64269  2020        14
# 6134             Lee County, Virginia      23723   35006  2016        14
# 6135        Isabella County, Michigan      70363   46783  2014        15
# 6136        Isabella County, Michigan      70363   46783  2014        15
# 6137        Isabella County, Michigan      70363   46783  2014        15
#
#      SUBSECTOR_ID GAS_ID CO2E_EMISSION
# 0              73    NaN           NaN
# 1              73    NaN           NaN
# 2              73    NaN           NaN
# 3              53      1         21826
# 4              53      2      15831.25
# ...           ...    ...           ...
# 6133           24      1         46319
# 6134           61      1            .1
# 6135           53      1       50224.9
# 6136           53      2         26883
# 6137           53      3        32.482
#
# [6138 rows x 18 columns]

# %% [markdown]
# More data at least, but again we're making some calls here we'd want to be really sure about in the real world.
#
# Original question: Aggregate total emissions for a facility for each year (i.e. all gases)

# %% [markdown]
# #### Cast to correct datatypes

# %% [markdown]
# All our columns are strings right now. In order to calculate we need the emissions column to be numeric, and might want other values (e.g. mhi, population, year) numeric as well
#
# Python datatypes: https://docs.python.org/3/library/stdtypes.html

# %%
df.dtypes
# Out:
# FACILITY_ID                object
# LATITUDE                   object
# LONGITUDE                  object
# CITY                       object
# ZIP                        object
# COUNTY_FIPS                object
# FACILITY_NAME              object
# REPORTED_SUBPARTS          object
# REPORTED_INDUSTRY_TYPES    object
# FACILITY_TYPES             object
# name                       object
# population                 object
# mhi                        object
# YEAR                       object
# SECTOR_ID                  object
# SUBSECTOR_ID               object
# GAS_ID                     object
# CO2E_EMISSION              object
# dtype: object

# %%
df_final = df.astype({'YEAR': 'int32', 'mhi': 'float', 'population': 'int', 'CO2E_EMISSION': 'float'})

# %%
df_final.dtypes
# Out:
# FACILITY_ID                 object
# LATITUDE                    object
# LONGITUDE                   object
# CITY                        object
# ZIP                         object
# COUNTY_FIPS                 object
# FACILITY_NAME               object
# REPORTED_SUBPARTS           object
# REPORTED_INDUSTRY_TYPES     object
# FACILITY_TYPES              object
# name                        object
# population                   int32
# mhi                        float64
# YEAR                         int32
# SECTOR_ID                   object
# SUBSECTOR_ID                object
# GAS_ID                      object
# CO2E_EMISSION              float64
# dtype: object

# %%
df_final.groupby(['FACILITY_ID', 'YEAR']).agg({'CO2E_EMISSION':['sum']})
# Out:
#                  CO2E_EMISSION
#                            sum
# FACILITY_ID YEAR
# 1000001     2017    350890.100
# 1000003     2017     80158.800
# 1000004     2017     57851.200
# 1000010     2017    107562.000
# 1000011     2013     28696.000
# ...                        ...
# 1011828     2016        13.410
# 1011987     2018     26644.800
# 1012682     2016        19.072
# 1012685     2016        14.304
# 1012844     2017    345489.264
#
# [3167 rows x 1 columns]

# %% [markdown]
# **CHALLENGE:**
# 1. Join the sector and ghg tables to add context for the emissions data
# 2. calculate the % each gas type makes up for a facilitity (total and/or per year)

# %% [markdown]
# ## Load
#
# The final step of ETL is **Load** - aka putting the data in a final destination.
#
# Examples:
# * write to a local file (e.g. JSON, CSV)
# * insert into a database
# * write to a file system (e.g. AWS S3 bucket)
# * upload to central repository
#     * datalake: raw data (unstructured or semi-structured)
#     * datawarehouse: all data; has usually been processed to some extent
#     * datamart: datawareshouse subset curated for a particular business use case

# %% [markdown]
# Here we'll be writing our final dataframe to a local csv file:

# %%
path = f'{os.getcwd()}\\data'
if not os.path.exists(path):
    os.makedirs(path)

# %%
df.to_csv('data/census_ghg.csv')

# %% [markdown]
# ### Sources
# * https://restfulapi.net/
# * https://www.ibm.com/cloud/learn/etl
# * https://www.redhat.com/en/topics/api/what-is-a-rest-api
# * https://www.ibm.com/cloud/blog/cloud-data-lake-vs-data-warehouse-vs-data-mart
